# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import plotly.graph_objects as go

# %%
dataset6=pd.read_csv('alldatasetconcat.csv')

# %%
dataset6
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Sr.No. Cut Off Merit (Score)  \
# 0              0             0               0       1             145 (207)
# 1              1             1               1       2             267 (191)
# 2              2             2               2       3             310 (187)
# 3              3             3               3       4             353 (182)
# 4              4             4               4       5             437 (175)
# 5              5             5               5       6             472 (173)
# 6              6             6               6       7             511 (170)
# 7              7             7               7       8             606 (164)
# 8              8             8               8       9             641 (163)
# 9              9             9               9      10             646 (163)
# 10            10            10              10      11             769 (156)
# ...

# %%
import sklearn as sk

from sklearn.preprocessing import LabelEncoder
dataset6['Cut Off Merit (Score)']=LabelEncoder().fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-963492faf7d3> in <module>
#       2
#       3 from sklearn.preprocessing import LabelEncoder
# ----> 4 dataset6['Cut Off Merit (Score)']=LabelEncoder().fit_transform(x)
#
# NameError: name 'x' is not defined

# %%
#colaberative filetering 

branch_ratingCount=dataset6.groupby(by=['Institute'])['score'].count()

# %%
branch_ratingCount
# Out:
# Institute
# 1101 - Shri Sant Gajanan Maharaj College of Engineering,Shegaon                                                                        23
# 1105 - Prof. Ram Meghe Institute of Technology & Research, Amravati                                                                    46
# 1107 - P. R. Pote (Patil) Education & Welfare Trust's Group of Institution(Integrated\nCampus), Amravati                               25
# 1107 - P. R. Pote (Patil) Education & Welfare Trust's Group of Institution(Integrated Cam                                               1
# 1114 - Sipna Shikshan Prasarak Mandal College of Engineering & Technology, Amravati                                                    24
# 1116 - Shri Shivaji Education Society's College of Engineering and Technology, Akola                                                   25
# 1117 - Janata Shikshan Prasarak Mandal'/s Babasaheb Naik College Of Engineering,\nPusad                                                 6
# ...

# %%
dataset6['Course Name']=LabelEncoder().fit_transform(y)

# %%
dataset6['Exam (JEE/MHT- CET)']=LabelEncoder().fit_transform(z)

# %%
x=dataset6['Cut Off Merit (Score)']
y=dataset6['Course Name']
z=dataset6['Exam (JEE/MHT- CET)']

# %%
dataset6[dataset6['Course Name'].isnull()].index.tolist()
# Out:
# []

# %%
dataset6= dataset6.drop([1117])

# %%
x=dataset6['Cut Off Merit (Score)']
y=dataset6['Course Name']
z=dataset6['Exam (JEE/MHT- CET)']

# %%
import plotly.express as px
#df = px.data.iris()
fig = px.scatter_3d(z_data, x=x, y=y, z=z)
fig.show()
# Out:
# <div>
#
#
#             <div id="51ed4b71-4d7e-4f67-8b05-cce0740eb87a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("51ed4b71-4d7e-4f67-8b05-cce0740eb87a")) {
#                     Plotly.newPlot(
#                         '51ed4b71-4d7e-4f67-8b05-cce0740eb87a',
# ...

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 6581 artists>

# %%
import seaborn as sns
sns.catplot(x=x, y=y, jitter=False, data=dataset6);
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-82ebb024a57c> in <module>
#       1 import seaborn as sns
# ----> 2 sns.catplot(x=x, y=y, jitter=False, data=dataset6);
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3753
#    3754     # Draw the plot onto the facets
# -> 3755     g.map_dataframe(plot_func, x, y, hue, **plot_kws)
#    3756
#    3757     # Special case axis labels for a count type plot
#
# ...

# %%
sns.distplot(x,y)

# %%
sns.relplot(x,y,data=dataset6,hue=z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-75e74338db01> in <module>
# ----> 1 sns.relplot(x,y,data=dataset6,hue=z)
#
# ~\Anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1611     g.map_dataframe(func, x, y,
#    1612                     hue=hue, size=size, style=style,
# -> 1613                     **plot_kws)
#    1614
#    1615     # Show the legend
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     821
#     822         # Finalize the annotations and layout
# --> 823         self._finalize_grid(args[:2])
#     824
#     825         return self
#
# ...
