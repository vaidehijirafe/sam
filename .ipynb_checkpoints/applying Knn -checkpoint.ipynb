# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset6=pd.read_csv('dataset1.csv')

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import LabelEncoder

model_knn=NearestNeighbors(metric='cosine',algorithm='brute')

# %%
#applying the model
#defining the x and y 

y=dataset6['Course Name']

x=dataset6.drop(columns=['Course Name'])
z=dataset6.Institute

# %%
dataset6
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Sr.No. Cut Off Merit (Score)  \
# 0              0             0               1       1             145 (207)
# 1              1             1               2       2             267 (191)
# 2              2             2               3       3             310 (187)
# 3              3             3               4       4             353 (182)
# 4              4             4               5       5             437 (175)
# ...          ...           ...             ...     ...                   ...
# 1112        1112          1112            1113    1113           104528 (39)
# 1113        1113          1113            1114    1114           104549 (39)
# 1114        1114          1114            1115    1115           104551 (39)
# 1115        1115          1115            1116    1116           104578 (39)
# 1116        1116          1116            1117    1117           104644 (38)
#
#      Choice Code                                          Institute  \
# 0      321524510  3215 - Bhartiya Vidya Bhavan's Sardar Patel In...
# 1      617519110  6175 - Pimpri Chinchwad Education Trust, Pimpr...
# 2      303650710  3036 - Institute of Chemical Technology, Matun...
# 3      627124510  6271 - Pune Institute of Computer Technology, ...
# 4      321524610  3215 - Bhartiya Vidya Bhavan's Sardar Patel In...
# ...          ...                                                ...
# 1112   660924510        6609 - Jaihind College Of Engineering,Kuran
# 1113   343624510  3436 - B.R. Harne College of Engineering & Tec...
# 1114   631529310  6315 - Holy-Wood Academy's Sanjeevan Engineeri...
# 1115   663224510  6632 - Navsahyadri Education Society's Group o...
# 1116   632524510  6325 - Alard  Charitable Trust's Alard College...
#
#                  Course Name Exam (JEE/MHT- CET)      Type Seat Type  score
# 0       Computer Engineering                 JEE  AI to AI        AI    207
# 1          Civil Engineering                 JEE  AI to AI        AI    191
# 2       Chemical Engineering                 JEE  AI to AI        AI    187
# 3       Computer Engineering                 JEE  AI to AI        AI    182
# 4     Information Technology                 JEE  AI to AI        AI    175
# ...                      ...                 ...       ...       ...    ...
# 1112    Computer Engineering                 CET  AI to AI        AI     39
# 1113    Computer Engineering                 CET  MH to AI     GNT1H     39
# 1114  Electrical Engineering                 CET  AI to AI        AI     39
# 1115    Computer Engineering                 CET  AI to AI        AI     39
# 1116    Computer Engineering                 CET  MI to AI        MI     38
#
# [1117 rows x 12 columns]

# %%
x.isna().sum()
# Out:
# Unnamed: 0               0
# Unnamed: 0.1             0
# Unnamed: 0.1.1           0
# Sr.No.                   0
# Cut Off Merit (Score)    0
# Choice Code              0
# Institute                0
# Exam (JEE/MHT- CET)      0
# Type                     0
# Seat Type                0
# score                    0
# dtype: int64

# %%
x.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Sr.No.',
#        'Cut Off Merit (Score)', 'Choice Code', 'Institute',
#        'Exam (JEE/MHT- CET)', 'Type', 'Seat Type', 'score'],
#       dtype='object')

# %%
x=x[['Exam (JEE/MHT- CET)', 'Type', 'Seat Type', 'score']]

# %%
x['Type']=LabelEncoder().fit_transform(x['Type'])
x['Seat Type']=LabelEncoder().fit_transform(x['Seat Type'])
x['Exam (JEE/MHT- CET)']=LabelEncoder().fit_transform(x['Exam (JEE/MHT- CET)'])
x['Type']=LabelEncoder().fit_transform(x['Type'])
#x['Institute']=LabelEncoder().fit_transform(x['Institute'])
#x['Choice Code']=LabelEncoder().fit_transform(x['Choice Code'])

# %%
#from sklearn.model_selection import train_test_split
model_knn=model_knn.fit(x,y)

# %%
model_knn
# Out:
# NearestNeighbors(algorithm='brute', leaf_size=30, metric='cosine',
#                  metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                  radius=1.0)

# %%
score=dataset6.score

# %%
distances,indices=model_knn.kneighbors(x.iloc[11].values.reshape(1,-1),n_neighbors=5)
for i in range(0,len(distances.flatten())):
    if i==0:
        print('its the same',y[indices.flatten()[i]], distances.flatten()[i])
    else:
        print(y[indices.flatten()[i]], distances.flatten()[i],z[indices.flatten()[i]],score[indices.flatten()[i]])
# Out:
# its the same Computer Engineering 0.0
# Electronics and Telecommunication
# Engg 0.0 3215 - Bhartiya Vidya Bhavan's Sardar Patel Institute  of Technology , Andheri, Mumbai 150
# Computer Engineering 0.0 6273 - Bansilal Ramnath Agarawal Charitable Trust's Vishwakarma Institute of
# Technology, Bibwewadi, Pune 150
# Information Technology 9.254563337890431e-09 6273 - Bansilal Ramnath Agarawal Charitable Trust's Vishwakarma Institute of
# Technology, Bibwewadi, Pune 147
# Surface Coating Technology 1.667869575783243e-08 3036 - Institute of Chemical Technology, Matunga, Mumbai 146

# %%
dataset6.iloc[11]
# Out:
# Unnamed: 0                                                              11
# Unnamed: 0.1                                                            11
# Unnamed: 0.1.1                                                          12
# Sr.No.                                                                  12
# Cut Off Merit (Score)                                            920 (150)
# Choice Code                                                      627324510
# Institute                6273 - Bansilal Ramnath Agarawal Charitable Tr...
# Course Name                                           Computer Engineering
# Exam (JEE/MHT- CET)                                                    JEE
# Type                                                              AI to AI
# Seat Type                                                               AI
# score                                                                  150
# Name: 11, dtype: object

# %%
x
# Out:
#       Exam (JEE/MHT- CET)  Type  Seat Type  score
# 0                       1     0          0    207
# 1                       1     0          0    191
# 2                       1     0          0    187
# 3                       1     0          0    182
# 4                       1     0          0    175
# ...                   ...   ...        ...    ...
# 1112                    0     0          0     39
# 1113                    0     1          2     39
# 1114                    0     0          0     39
# 1115                    0     0          0     39
# 1116                    0     2         30     38
#
# [1117 rows x 4 columns]

# %%
for i in range(0,len(distances.flatten())):
    if i==0:
        print('its the same',y[indices.flatten()[i]], distances.flatten()[i])
    else:
        print(y[indices.flatten()[i]], distances.flatten()[i])
# Out:
# its the same Computer Engineering 0.0
# Computer Engineering 1.5130110986305567e-07
# Information Technology 5.808137666374336e-07
# Computer Engineering 8.576646781666142e-07
# Food Engineering and Technology 1.486209004442074e-05

# %%
# Out:
# input the Exam (JEE/MHT- CET) expected type is <class 'str'>JEE
# JEE
# 1
# input the Type expected type is <class 'str'>AI to AI
# AI to AI
# 0
# input the Seat Type expected type is <class 'str'>AI
# AI
# 0

# %%
dataset6
# Out:
#       Sr.No.  Unnamed: 0  Sr.No..1  Sr.No..1.1 Cut Off Merit (Score)  \
# 0          1           0         1           1             145 (207)
# 1          2           1         2           2             267 (191)
# 2          3           2         3           3             310 (187)
# 3          4           3         4           4             353 (182)
# 4          5           4         5           5             437 (175)
# 5          6           5         6           6             472 (173)
# 6          7           6         7           7             511 (170)
# 7          8           7         8           8             606 (164)
# 8          9           8         9           9             641 (163)
# 9         10           9        10          10             646 (163)
# 2                              Chemical Engineering                 JEE
# 3                              Computer Engineering                 JEE
# 4                            Information Technology                 JEE
# 5                   Food Engineering and Technology                 JEE
# 6                              Computer Engineering                 JEE
# 7                            Mechanical Engineering                 JEE
# 8                              Computer Engineering                 JEE
# 9                            Information Technology                 JEE
# 10                           Information Technology                 JEE
# 11                             Computer Engineering                 JEE
# 12          Electronics and Telecommunication\nEngg                 JEE
# 13                             Computer Engineering                 JEE
# 14                           Information Technology                 JEE
# 15                       Surface Coating Technology                 JEE
# 16                 Computer Science and Engineering                 JEE
# 17                             Computer Engineering                 JEE
# 18                           Information Technology                 JEE
# 19                          Electronics Engineering                 JEE
# 20                           Information Technology                 JEE
# 21    Oil,Oleochemicals and Surfactants\nTechnology                 JEE
# 22          Electronics and Telecommunication\nEngg                 JEE
# 23                             Computer Engineering                 JEE
# 24                           Mechanical Engineering                 JEE
# 25          Electronics and Telecommunication\nEngg                 JEE
# 26          Electronics and Telecommunication\nEngg                 JEE
# 27                             Computer Engineering                 JEE
# 28                             Computer Engineering                 JEE
# 29                           Mechanical Engineering                 JEE
# ...                                             ...                 ...
# 6551                         Mechanical Engineering                 CET
# 6552                         Mechanical Engineering                 CET
# 6553                         Electrical Engineering                 CET
# 6554                         Mechanical Engineering                 CET
# 6555                         Mechanical Engineering                 CET
# 6556                         Mechanical Engineering                 CET
# 6557                         Information Technology                 CET
# 6558                              Civil Engineering                 CET
# 6559        Electronics and Telecommunication\nEngg                 CET
# 6560                              Civil Engineering                 CET
# 6561                              Civil Engineering                 CET
# 6562                         Mechanical Engineering                 CET
# 6563                         Information Technology                 CET
# 6564                           Computer Engineering                 CET
# 6565                         Mechanical Engineering                 CET
# 6566                         Electrical Engineering                 CET
# 6567                         Electrical Engineering                 CET
# 6568                         Electrical Engineering                 CET
# 6569                              Civil Engineering                 CET
# 6570        Electronics and Telecommunication\nEngg                 CET
# 6571                         Mechanical Engineering                 CET
# 6572        Electronics and Telecommunication\nEngg                 CET
# 6573                              Civil Engineering                 CET
# 6574               Computer Science and Engineering                 CET
# 6575                         Electrical Engineering                 CET
# 6576                         Mechanical Engineering                 CET
# 6577                         Mechanical Engineering                 CET
# 6578                         Mechanical Engineering                 CET
# 6579                              Civil Engineering                 CET
# 6580                         Information Technology                 CET
#
#           Type Seat Type  score     rank
# 0     AI to AI        AI    207     145
# 1     AI to AI        AI    191     267
# 2     AI to AI        AI    187     310
# 3     AI to AI        AI    182     353
# 4     AI to AI        AI    175     437
# 5     AI to AI        AI    173     472
# 6     AI to AI        AI    170     511
# 7     AI to AI        AI    164     606
# 8     AI to AI        AI    163     641
# 9     AI to AI        AI    163     646
# 10    AI to AI        AI    156     769
# 11    AI to AI        AI    150     920
# 12    AI to AI        AI    150     921
# 13    AI to AI        AI    150     922
# 14    AI to AI        AI    147    1018
# 15    AI to AI        AI    146    1044
# 16    AI to AI        AI    142    1160
# 17    AI to AI        AI    137    1337
# 18    AI to AI        AI    135    1429
# 19    AI to AI        AI    134    1449
# 20    AI to AI        AI    134    1465
# 21    AI to AI        AI    133    1493
# 22    AI to AI        AI    132    1511
# 23    AI to AI        AI    132    1515
# 24    AI to AI        AI    130    1594
# 25    AI to AI        AI    130    1634
# 26    AI to AI        AI    128    1669
# 27    AI to AI        AI    125    1810
# 28    AI to AI        AI    124    1882
# 29    AI to AI        AI    124    1890
# ...        ...       ...    ...      ...
# 6551  AI to AI        AI     42  103898
# 6552  AI to AI        AI     42  103913
# 6553  AI to AI        AI     42  103925
# 6554  MI to AI        MI     42  103949
# 6555  AI to AI        AI     42  103960
# 6556  AI to AI        AI     42  103990
# 6557  MI to AI        MI     42  104073
# 6558  AI to AI        AI     42  104112
# 6559  AI to AI        AI     41  104244
# 6560  AI to AI        AI     40  104391
# 6561  AI to AI        AI     39  104481
# 6562  AI to AI        AI     39  104514
# 6563  AI to AI        AI     39  104567
# 6564  AI to AI        AI     39  104577
# 6565  AI to AI        AI     39  104598
# 6566  AI to AI        AI     38  104606
# 6567  AI to AI        AI     38  104630
# 6568  AI to AI        AI     38  104642
# 6569  AI to AI        AI     38  104652
# 6570  AI to AI        AI     37  104685
# 6571  AI to AI        AI     37  104695
# 6572  AI to AI        AI     36  104732
# 6573  AI to AI        AI     36  104736
# 6574  AI to AI        AI     36  104739
# 6575  AI to AI        AI     36  104770
# 6576  AI to AI        AI     35  104786
# 6577  AI to AI        AI     35  104797
# 6578  AI to AI        AI     34  104832
# 6579  AI to AI        AI     30  104889
# 6580  AI to AI        AI     29  104901
#
# [6581 rows x 13 columns]

# %%
r
# Out:
# {'Sr.No..1.1': 1,
#  'Exam (JEE/MHT- CET)': '1',
#  'Type': '1',
#  'Seat Type': '1',
#  'score': 1}

# %%
x['branch']=y

# %%
x['branch']=LabelEncoder().fit_transform(x['branch'])

# %%
labels,unique=pd.factorize(dataset6['Seat Type'])

# %%
unique
# Out:
# Index(['AI', 'GNT2H', 'GNT1H', 'LOPENO', 'GSCO', 'GOPENO', 'LNT2H', 'LSCH',
#        'LOPENH', 'GSCH', 'GSTO', 'LOBCH', 'GOPENH', 'GOBCH', 'GNT3H', 'LOBCO',
#        'MI', 'GSTH', 'GNT3O', 'LSTH', 'LNT1H', 'GNT1O', 'PHCH', 'LSCO', 'GVJO',
#        'GVJH', 'GOBCO', 'LNT3H', 'DEFO', 'LSTO', 'GNT2O', 'LVJH', 'LVJO',
#        'PH3H', 'PH2H', 'PH1H'],
#       dtype='object')

# %%
z=x['Seat Type']

# %%
df3={}
dat=pd.DataFrame(columns=['true'])
for i in range(len(labels)):
    #x.loc[i,'Seat Type']
    #labels[1]
    if(x.loc[i,'Seat Type']==labels[i]):
        df3['true']='true'
    else:
        df3['true']='false'
    dat=dat.append(df3,ignore_index=True)    
    i=i+1

# %%
dat['true'].value_counts().plot(kind='bar')

# %%
sam=dat.groupby(dat['true'])

# %%
len(sam.get_group('true'))
# Out:
# 5759

# %%
sam.get_group('false')
# Out:
#        true
# 97    false
# 247   false
# 303   false
# 325   false
# 355   false
# 364   false
# 373   false
# 380   false
# 467   false
# 480   false
# 496   false
# 503   false
# 518   false
# 531   false
# 533   false
# 534   false
# 541   false
# 544   false
# 547   false
# 548   false
# 549   false
# 560   false
# 568   false
# 569   false
# 582   false
# 587   false
# 590   false
# 598   false
# 599   false
# 616   false
# ...     ...
# 6298  false
# 6301  false
# 6302  false
# 6320  false
# 6332  false
# 6333  false
# 6341  false
# 6348  false
# 6349  false
# 6352  false
# 6363  false
# 6364  false
# 6374  false
# 6382  false
# 6389  false
# 6396  false
# 6400  false
# 6415  false
# 6417  false
# 6424  false
# 6429  false
# 6435  false
# 6439  false
# 6469  false
# 6477  false
# 6482  false
# 6506  false
# 6512  false
# 6554  false
# 6557  false
#
# [822 rows x 1 columns]

# %%
labels[97],x.loc[97,'Seat Type']
# Out:
# (1, 4)

# %%
labels[97],dataset6.loc[97,'Seat Type']
# Out:
# (1, 'GNT2H')

# %%
6581-5759
# Out:
# 822

# %%
# Out:
# 0.1249050296307552

# %%
distances,indices=model_knn.kneighbors(x.iloc[119].values.reshape(1,-1),n_neighbors=15)

# %%
df={}

df3=pd.DataFrame(columns=['branches','colrative_index'])
for i in range(0,len(distances.flatten())):
    if i==0:
        
        
        print('its the same',y[indices.flatten()[i]], distances.flatten()[i])
    else:
        print(y[indices.flatten()[i]], distances.flatten()[i])
        df['branch name']=y[indices.flatten()[i]]
        df['colrative_index']=distances.flatten()[i]
        df3=df3.append(df,ignore_index=True)
# Out:
# its the same Electronics and Telecommunication
# Engg 0.0
# Mechanical Engineering 0.0
# Instrumentation Engineering 0.0
# Civil Engineering 0.0
# Electronics Engineering 0.0
# Mechanical Engineering 0.0
# Instrumentation Engineering 0.0
# Computer Engineering 0.0
# Information Technology 0.0
# Mechanical Engineering 0.0
# Electronics and Telecommunication
# Engg 0.0
# Computer Engineering 0.0
# Computer Engineering 0.0
# Computer Engineering 0.0
# Computer Engineering 0.0

# %%
df3.drop(columns=['branches'])
# Out:
#     colrative_index                              branch name
# 0               0.0                   Mechanical Engineering
# 1               0.0              Instrumentation Engineering
# 2               0.0                        Civil Engineering
# 3               0.0                  Electronics Engineering
# 4               0.0                   Mechanical Engineering
# 5               0.0              Instrumentation Engineering
# 6               0.0                     Computer Engineering
# 7               0.0                   Information Technology
# 8               0.0                   Mechanical Engineering
# 9               0.0  Electronics and Telecommunication\nEngg
# 10              0.0                     Computer Engineering
# 11              0.0                     Computer Engineering
# 12              0.0                     Computer Engineering
# 13              0.0                     Computer Engineering

# %%
recocmmended_brancehs=pd.DataFrame(df3['branch name'].unique())
recocmmended_brancehs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-602f39192674> in <module>
# ----> 1 recocmmended_brancehs=pd.DataFrame(df3['branch name'].unique())
#       2 recocmmended_brancehs
#
# NameError: name 'df3' is not defined

# %% [markdown]
# # to get the input

# %%
dataset6.iloc[110]
# Out:
# Unnamed: 0                                                             110
# Unnamed: 0.1                                                           110
# Unnamed: 0.1.1                                                         111
# Sr.No.                                                                 111
# Cut Off Merit (Score)                                            6262 (80)
# Choice Code                                                      319024510
# Institute                3190 - Terna Engineering College, Nerul, Navi ...
# Course Name                                           Computer Engineering
# Exam (JEE/MHT- CET)                                                    JEE
# Type                                                              AI to AI
# Seat Type                                                               AI
# score                                                                   80
# Name: 110, dtype: object

# %%
#giving the input to the model 
r={}
def to_int(x):
    return int(x)
for i in range(len(x.columns)):
        
    typ=type(dataset6[x.iloc[:,i].name][0])
    r[x.iloc[:,i].name]=typ(input("input the "+x.iloc[:,i].name+" expected type is "+str(typ)))
    
    if(typ==str):
        v=r[x.iloc[:,i].name]
        c=x.iloc[:,i].name
        print(v)
        k=dataset6[dataset6[c]==v].index
        if(len(k)>1):
            k=k[0]
            v=x[x.iloc[:,i].name][k]
        else:
            v=x[x.iloc[:,i].name][k]
        r[c]=v
        to_int(r[c])
        print(r[c])
# Out:
# input the Exam (JEE/MHT- CET) expected type is <class 'str'>JEE
# JEE
# 1
# input the Type expected type is <class 'str'>AI to AI
# AI to AI
# 0
# input the Seat Type expected type is <class 'str'>AI
# AI
# 0
# input the score expected type is <class 'numpy.int64'>145

# %%
r=pd.DataFrame([r])

# %%
import pickle

pickle.dump(model_knn,open("knn2.pkl",'wb'))

# %%
m_knn=pickle.load(open('knn2.pkl','rb'))

# %%
dist,indi=m_knn.kneighbors(r.iloc[0].values.reshape(1,-1),n_neighbors=15)
print(dist)
# Out:
# [[1.11554543e-09 4.40168102e-09 1.06134757e-08 2.64211391e-08
#   2.64211391e-08 2.64211391e-08 8.10828605e-08 1.18231091e-07
#   1.30473408e-07 1.60237797e-07 1.60237797e-07 1.93574455e-07
#   2.30636114e-07 2.30636114e-07 2.89979210e-07]]

# %%
for i in range(len(indi.flatten())):
    print(z[indi.flatten()[i]],score[indi.flatten()[i]])
# Out:
# 3036 - Institute of Chemical Technology, Matunga, Mumbai 146
# 6273 - Bansilal Ramnath Agarawal Charitable Trust's Vishwakarma Institute of
# Technology, Bibwewadi, Pune 147
# 4115 - Shri Ramdeobaba College of Engineering and Management, Nagpur 142
# 6273 - Bansilal Ramnath Agarawal Charitable Trust's Vishwakarma Institute of
# Technology, Bibwewadi, Pune 150
# 3215 - Bhartiya Vidya Bhavan's Sardar Patel Institute  of Technology , Andheri, Mumbai 150
# 3181 - K.J.Somaiya College of Engineering, Vidyavihar, Mumbai 150
# 3182 - Thadomal Shahani Engineering College, Bandra, Mumbai 137
# 3199 - Shri Vile Parle Kelvani Mandal's Dwarkadas J. Sanghvi College of Engineering,
# Vile Parle,Mumbai 156
# 4115 - Shri Ramdeobaba College of Engineering and Management, Nagpur 135
# 3181 - K.J.Somaiya College of Engineering, Vidyavihar, Mumbai 134
# 3215 - Bhartiya Vidya Bhavan's Sardar Patel Institute  of Technology , Andheri, Mumbai 134
# 3036 - Institute of Chemical Technology, Matunga, Mumbai 133
# 3184 - Fr. Conceicao Rodrigues College of Engineering, Bandra,Mumbai 132
# 3199 - Shri Vile Parle Kelvani Mandal's Dwarkadas J. Sanghvi College of Engineering,
# Vile Parle,Mumbai 132
# 6271 - Pune Institute of Computer Technology, Dhankavdi, Pune 163
