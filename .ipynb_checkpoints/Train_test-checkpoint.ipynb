# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import plotly.graph_objects as go
import sklearn as sk

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
model_knn=KNeighborsClassifier()

# %%
# reading all the dataset
fulldata=pd.read_csv('alldatasetconcat.csv')
fulldata
fulldata.index=fulldata['Sr.No.']
fulldata.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1','rank','Sr.No.'],inplace=True)
fulldata
# Out:
#        Cut Off Merit (Score) Choice Code  \
# Sr.No.
# 1                  145 (207)   321524510
# 2                  267 (191)   617519110
# 3                  310 (187)   303650710
# 4                  353 (182)   627124510
# 5                  437 (175)   321524610
# 6                  472 (173)   303653410
# 7                  511 (170)   627124520
# 8                  606 (164)   318161210
# 9                  641 (163)   319924510
# 10                 646 (163)   627124610
# 11                 769 (156)   319924610
# 12                 920 (150)   627324510
# 13                 921 (150)   321537210
# 14                 922 (150)   318124510
# 15                1018 (147)   627324610
# 16                1044 (146)   303672910
# 17                1160 (142)   411524220
# 18                1337 (137)   318224510
# 19                1429 (135)   411524610
# 20                1449 (134)   321537610
# 21                1465 (134)   318124610
# 22                1493 (133)   303651210
# 23                1511 (132)   319937210
# 24                1515 (132)   318424510
# 25                1594 (130)   319961210
# 26                1634 (130)   627337210
# 27                1669 (128)   627137220
# 28                1810 (125)   319724510
# 29                1882 (124)   318524510
# 30                1890 (124)   411561210
# ...                      ...         ...
# 1169             103898 (42)   211361220
# 1170             103913 (42)   631561210
# 1171             103925 (42)   646629310
# 1172             103949 (42)   321861210
# 1173             103960 (42)   620361210
# 1174             103990 (42)   675561220
# 1175             104073 (42)   322224610
# 1176             104112 (42)   418719110
# 1177             104244 (41)   664337210
# 1178             104391 (40)   544919110
# 1179             104481 (39)   127619110
# 1180             104514 (39)   632361210
# 1181             104567 (39)   418624610
# 1182             104577 (39)   512424510
# 1183             104598 (39)   533161210
# 1184             104606 (38)   112829310
# 1185             104630 (38)   512529310
# 1186             104642 (38)   253329310
# 1187             104652 (38)   213419110
# 1188             104685 (37)   617837220
# 1189             104695 (37)   110761210
# 1190             104732 (36)   680337210
# 1191             104736 (36)   678619110
# 1192             104739 (36)   211224210
# 1193             104770 (36)   410429310
# 1194             104786 (35)   664361210
# 1195             104797 (35)   664361210
# 1196             104832 (34)   346761210
# 1197             104889 (30)   416319110
# 1198             104901 (29)   111924610
#
#                                                 Institute  \
# Sr.No.
# 1       3215 - Bhartiya Vidya Bhavan's Sardar Patel In...
# 2       6175 - Pimpri Chinchwad Education Trust, Pimpr...
# 3       3036 - Institute of Chemical Technology, Matun...
# 4       6271 - Pune Institute of Computer Technology, ...
# 5       3215 - Bhartiya Vidya Bhavan's Sardar Patel In...
# 6       3036 - Institute of Chemical Technology, Matun...
# 7       6271 - Pune Institute of Computer Technology, ...
# 8       3181 - K.J.Somaiya College of Engineering, Vid...
# 9       3199 - Shri Vile Parle Kelvani Mandal's Dwarka...
# 10      6271 - Pune Institute of Computer Technology, ...
# 11      3199 - Shri Vile Parle Kelvani Mandal's Dwarka...
# 12      6273 - Bansilal Ramnath Agarawal Charitable Tr...
# 13      3215 - Bhartiya Vidya Bhavan's Sardar Patel In...
# 14      3181 - K.J.Somaiya College of Engineering, Vid...
# 15      6273 - Bansilal Ramnath Agarawal Charitable Tr...
# 16      3036 - Institute of Chemical Technology, Matun...
# 17      4115 - Shri Ramdeobaba College of Engineering ...
# 18      3182 - Thadomal Shahani Engineering College, B...
# 19      4115 - Shri Ramdeobaba College of Engineering ...
# 20      3215 - Bhartiya Vidya Bhavan's Sardar Patel In...
# 21      3181 - K.J.Somaiya College of Engineering, Vid...
# 22      3036 - Institute of Chemical Technology, Matun...
# 23      3199 - Shri Vile Parle Kelvani Mandal's Dwarka...
# 24      3184 - Fr. Conceicao Rodrigues College of Engi...
# 25      3199 - Shri Vile Parle Kelvani Mandal's Dwarka...
#
# 1179                                Civil Engineering                 CET
# 1180                           Mechanical Engineering                 CET
# 1181                           Information Technology                 CET
# 1182                             Computer Engineering                 CET
# 1183                           Mechanical Engineering                 CET
# 1184                           Electrical Engineering                 CET
# 1185                           Electrical Engineering                 CET
# 1186                           Electrical Engineering                 CET
# 1187                                Civil Engineering                 CET
# 1188          Electronics and Telecommunication\nEngg                 CET
# 1189                           Mechanical Engineering                 CET
# 1190          Electronics and Telecommunication\nEngg                 CET
# 1191                                Civil Engineering                 CET
# 1192                 Computer Science and Engineering                 CET
# 1193                           Electrical Engineering                 CET
# 1194                           Mechanical Engineering                 CET
# 1195                           Mechanical Engineering                 CET
# 1196                           Mechanical Engineering                 CET
# 1197                                Civil Engineering                 CET
# 1198                           Information Technology                 CET
#
#             Type Seat Type  score
# Sr.No.
# 1       AI to AI        AI    207
# 2       AI to AI        AI    191
# 3       AI to AI        AI    187
# 4       AI to AI        AI    182
# 5       AI to AI        AI    175
# 6       AI to AI        AI    173
# 7       AI to AI        AI    170
# 8       AI to AI        AI    164
# 9       AI to AI        AI    163
# 10      AI to AI        AI    163
# 11      AI to AI        AI    156
# 12      AI to AI        AI    150
# 13      AI to AI        AI    150
# 14      AI to AI        AI    150
# 15      AI to AI        AI    147
# 16      AI to AI        AI    146
# 17      AI to AI        AI    142
# 18      AI to AI        AI    137
# 19      AI to AI        AI    135
# 20      AI to AI        AI    134
# 21      AI to AI        AI    134
# 22      AI to AI        AI    133
# 23      AI to AI        AI    132
# 24      AI to AI        AI    132
# 25      AI to AI        AI    130
# 26      AI to AI        AI    130
# 27      AI to AI        AI    128
# 28      AI to AI        AI    125
# 29      AI to AI        AI    124
# 30      AI to AI        AI    124
# ...          ...       ...    ...
# 1169    AI to AI        AI     42
# 1170    AI to AI        AI     42
# 1171    AI to AI        AI     42
# 1172    MI to AI        MI     42
# 1173    AI to AI        AI     42
# 1174    AI to AI        AI     42
# 1175    MI to AI        MI     42
# 1176    AI to AI        AI     42
# 1177    AI to AI        AI     41
# 1178    AI to AI        AI     40
# 1179    AI to AI        AI     39
# 1180    AI to AI        AI     39
# 1181    AI to AI        AI     39
# 1182    AI to AI        AI     39
# 1183    AI to AI        AI     39
# 1184    AI to AI        AI     38
# 1185    AI to AI        AI     38
# 1186    AI to AI        AI     38
# 1187    AI to AI        AI     38
# 1188    AI to AI        AI     37
# 1189    AI to AI        AI     37
# 1190    AI to AI        AI     36
# 1191    AI to AI        AI     36
# 1192    AI to AI        AI     36
# 1193    AI to AI        AI     36
# 1194    AI to AI        AI     35
# 1195    AI to AI        AI     35
# 1196    AI to AI        AI     34
# 1197    AI to AI        AI     30
# 1198    AI to AI        AI     29
#
# [6581 rows x 8 columns]

# %%
x=fulldata.drop(columns=['Course Name'])
#applying the model
#defining the x and y 

y=fulldata['Course Name']

# %%
x['Type']=LabelEncoder().fit_transform(x['Type'])
x['Seat Type']=LabelEncoder().fit_transform(x['Seat Type'])
x['Exam (JEE/MHT- CET)']=LabelEncoder().fit_transform(x['Exam (JEE/MHT- CET)'])
x['Type']=LabelEncoder().fit_transform(x['Type'])
x['Institute']=LabelEncoder().fit_transform(x['Institute'])
x['Cut Off Merit (Score)']=LabelEncoder().fit_transform(x['Cut Off Merit (Score)'])
x['Choice Code']=LabelEncoder().fit_transform(x['Choice Code'])

# %%
import seaborn as sns
sns.heatmap(x.corr(),annot=True, cmap="YlGnBu")

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
classifier_knn=KNeighborsClassifier()

# %%
classifier_knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')
